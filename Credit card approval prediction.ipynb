# %%
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt
import seaborn as sns
sns.set()

# %%
application_details = pd.read_csv('C:/Users/ASUS\Desktop/Credit card approval/application_record.csv')
credit_record = pd.read_csv('C:/Users/ASUS\Desktop/Credit card approval/credit_record.csv')

# %%
application_details.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 438557 entries, 0 to 438556
# Data columns (total 18 columns):
#  #   Column               Non-Null Count   Dtype
# ---  ------               --------------   -----
#  0   ID                   438557 non-null  int64
#  1   CODE_GENDER          438557 non-null  object
#  2   FLAG_OWN_CAR         438557 non-null  object
#  3   FLAG_OWN_REALTY      438557 non-null  object
#  4   CNT_CHILDREN         438557 non-null  int64
#  5   AMT_INCOME_TOTAL     438557 non-null  float64
#  6   NAME_INCOME_TYPE     438557 non-null  object
#  7   NAME_EDUCATION_TYPE  438557 non-null  object
#  8   NAME_FAMILY_STATUS   438557 non-null  object
#  9   NAME_HOUSING_TYPE    438557 non-null  object
#  10  DAYS_BIRTH           438557 non-null  int64
#  11  DAYS_EMPLOYED        438557 non-null  int64
#  12  FLAG_MOBIL           438557 non-null  int64
#  13  FLAG_WORK_PHONE      438557 non-null  int64
#  14  FLAG_PHONE           438557 non-null  int64
# ...

# %%
credit_record.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1048575 entries, 0 to 1048574
# Data columns (total 3 columns):
#  #   Column          Non-Null Count    Dtype
# ---  ------          --------------    -----
#  0   ID              1048575 non-null  int64
#  1   MONTHS_BALANCE  1048575 non-null  int64
#  2   STATUS          1048575 non-null  object
# dtypes: int64(2), object(1)
# memory usage: 24.0+ MB

# %% [markdown]
# # Count Plot of Categorical Features: application_details

# %%
def countplot_applicants(features):
    for feature in features:
        plt.figure(figsize=(9, 9))
        ax=sns.countplot(y=application_details[feature], hue='CODE_GENDER' , data=application_details)
        plt.legend(loc='best')
        total = len(application_details[feature])
        for p in ax.patches:
            percentage = '{:.1f}%'.format(100 * p.get_width()/total)
            x = p.get_x() + p.get_width() + 0.02
            y = p.get_y() + p.get_height()/2
            ax.annotate(percentage, (x, y))
    plt.show()

# %%
countplot_applicants(['CODE_GENDER', 'FLAG_OWN_CAR', 'FLAG_OWN_REALTY', 'NAME_INCOME_TYPE', 'NAME_EDUCATION_TYPE', 'NAME_FAMILY_STATUS', 'NAME_HOUSING_TYPE', 'OCCUPATION_TYPE'])

# %% [markdown]
# #### 36.9% applications are male and 67.1% applications are female.
# #### 20.1%  male applicants and 17.1%  female applicants have a car.
# #### 12.8%  male applicants and 50%  female applicants does'nt have a car.
# #### 21.9% of the male applicants and 47.5% of the female applicants have property.
# #### 11%    of the male applicants and 19.7% of the female applicants does'nt have property.
# #### 19.4% of the male applicants and 32.2% of the female applicants are working.
# #### 8.4% of the male applicants and 14.5% of the female applicants are commercial assciates.
# #### 2.7% of the male applicants and 14.5% of the emale applicants are pensioner.
# #### 2.4% of male applicants and 5.9% of female applicants are state servents.
# #### 8.5% of male applicants and 18.3% of female applicants have completed their higher education.
# #### 22.5% of male applicants and 46.3% of female applicants have completed their secondary education.
# #### 1.4% of male applicants and 2% of female applicants did'nt completed their higher education.
# #### 0.4% of male applicants and 0.6% of female applicants did'nt completed their secondary education.
# #### 0% of male applicants and 0.1% of female applicants have academic degree.
# #### 2.2% of male applicants and 6.1% of female applicants have done civil marriage.
# #### 24.9% of male applicants and 43.5% of female applicants are married.
# #### 4.3% of male applicants and 8.3% of female applicants are single.
# #### 1.2% of male applicants and 5% of female applicants are seperated.
# #### 0.2% of male applicants and 4.3% of female applicants widow.
# #### 0.6% of male applicants and 0.7% of female applicants live in a rented apartment.
# #### 28.8% of male applicants and 61.0% of female applicants live in a apartment.
# #### 0.6% of male applicants and 0.7% of female applicants live in a rented apartment.
# #### 1% of male applicants and 2.3% of female applicants live in municipal apartment.
# #### 1.9% of male applicants and 2.4% of female applicants live with their parents.
# #### 0.4% of male applicants and 0.5% of female applicants live in office apartment.
# #### Occupation details:
# #### security staff: male-1.2% and female-0.6%
# #### sales staff: male-1.2% and female-8.2%
# #### accountant: male-0.1% and female-3.5%
# #### labours: male-10% and female-7.9%
# #### managers: male-3.5% and female-4.6%
# #### drivers: male-5.6% and female-0.4%
# #### core staff: male-2.1% and female-7.7%
# #### high skill tech staff: male-1.3% and female-2.6%
# #### cleaning staff: male-0.1% and female-1.3%
# #### private service staff: male-0% and female-0.8%
# #### cooking staff: male-0.2% and female-1.7%
# #### low-skill labourers: male-0.4% and female-0.1%
# #### medicine staff: male-0.1% and female-3%
# #### secrentances: male-0% and female-0.4%
# #### waiters/barmen staff: male-0.1% and female-0.3%
# #### hr staff: male-0% and female-0.2%
# #### realty agent: male-0% and female-0.2%
# #### it staff: male-0.1% and female-0%

# %% [markdown]
# # Count Plot of Categorical Features: credit_Record

# %%
def countplot_credit(features):
    for feature in features:
        plt.figure(figsize=(9, 9))
        ax=sns.countplot(y=credit_record[feature], data=credit_record)
        total = len(credit_record[feature])
        for p in ax.patches:
            percentage = '{:.1f}%'.format(100 * p.get_width()/total)
            x = p.get_x() + p.get_width() + 0.02
            y = p.get_y() + p.get_height()/2
            ax.annotate(percentage, (x, y))
    plt.show()

# %%
countplot_credit(['STATUS'])

# %% [markdown]
# ### Insights from the CountPlot Analysis: credit_record:
# #### C: loan for that month has already been paid
# #### X: no loan for that month
# #### 0: loan is 1 to 29 days overdue
# #### 1: loan is 30 to 59 days overdue
# #### 2: loan is 60 to 89 days overdue
# #### 3:loan is 90 to 119 days overdue
# #### 4: loan is 120 to 149 days overdue
# #### 5: loan is more than 150 days overdue
# #### .
# #### .
# #### 1)   20% of applicatnts does'nt have loan of the current month.
# #### 2)   36.5% of applicants have overdue for 1-29 days.
# #### 3)   42.2% of applicants already paid current month loan.
# #### 4)   1.1% of applicants have overdue for 30-59 days.
# #### 5)   0.1% of applicants have overdue for 60-89 days.
# #### 6)   0% of applicants have overdue for 90-119 days.
# #### 7)   0% of applicants have overdue for 120-149 days.
# #### 8)   0.2% of applicants have overdue for 150 days

# %% [markdown]
# # Data préparation

# %%
application_details['ID'].nunique()
# the total rows are 438,557. This means it has duplicates
# Out:
# 438510

# %%
credit_record['ID'].nunique() 
# this has around 43,000 unique rows as there are repeating entries for different monthly values and status.
# Out:
# 45985

# %%
len(set(credit_record['ID']).intersection(set(application_details['ID'])))
# checking to see how many records match in two datasets
# Out:
# 36457

# %%
sns.heatmap(application_details.isnull())
# checking for null values. Seems like occupation_type has many
# Out:
# <AxesSubplot:>

# %%
sns.heatmap(credit_record.isnull())
# checking for null values. no missing values here.
# Out:
# <AxesSubplot:>

# %%
application_details = application_details.drop_duplicates('ID', keep='last') 
# we identified that there are some duplicates in this dataset
# we will be deleting those duplicates and will keep the last entry of the ID if its repeated.

# %%
application_details.drop('OCCUPATION_TYPE', axis=1, inplace=True) 
#we identified earlier that occupation_type has many missing values
# we will drop this column
# Out:
# C:\Users\ASUS\anaconda3\lib\site-packages\pandas\core\frame.py:4906: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().drop(

# %%
ot = pd.DataFrame(application_details.dtypes =='object').reset_index()
object_type = ot[ot[0] == True]['index']
object_type
#we are filtering the columns that have non numeric values to see if they are useful
# Out:
# 1            CODE_GENDER
# 2           FLAG_OWN_CAR
# 3        FLAG_OWN_REALTY
# 6       NAME_INCOME_TYPE
# 7    NAME_EDUCATION_TYPE
# 8     NAME_FAMILY_STATUS
# 9      NAME_HOUSING_TYPE
# Name: index, dtype: object

# %%
num_type = pd.DataFrame(application_details.dtypes != 'object').reset_index().rename(columns =  {0:'yes/no'})
num_type = num_type[num_type['yes/no'] ==True]['index']
#HAVE CREATED SEPARATE LIST FOR NUMERIC TYPE INCASE IT WILL BE NEEDED IN FURTHER ANALYSIS
# IT IS NEEDED IN FURTHER ANALYSIS

# %%
a = application_details[object_type]['CODE_GENDER'].value_counts()
b = application_details[object_type]['FLAG_OWN_CAR'].value_counts()
c = application_details[object_type]['FLAG_OWN_REALTY'].value_counts()
d = application_details[object_type]['NAME_INCOME_TYPE'].value_counts()
e = application_details[object_type]['NAME_EDUCATION_TYPE'].value_counts()
f = application_details[object_type]['NAME_FAMILY_STATUS'].value_counts()
g = application_details[object_type]['NAME_HOUSING_TYPE'].value_counts()

print( a,"\n",b,'\n', c, '\n', d, '\n', e, '\n', f, '\n', g)

#this is just to see what each column is. 
#It seems that all of them are important since there is very fine classifcation in each column.
# their effectiveness cannot be judged at this moment so we convert all of them to numeric values.
# Out:
# F    294412
# M    144098
# Name: CODE_GENDER, dtype: int64
#  N    275428
# Y    163082
# Name: FLAG_OWN_CAR, dtype: int64
#  Y    304043
# N    134467
# Name: FLAG_OWN_REALTY, dtype: int64
#  Working                 226087
# Commercial associate    100739
# Pensioner                75483
# State servant            36184
# Student                     17
# Name: NAME_INCOME_TYPE, dtype: int64
#  Secondary / secondary special    301789
# Higher education                 117509
# Incomplete higher                 14849
# Lower secondary                    4051
# Academic degree                     312
# Name: NAME_EDUCATION_TYPE, dtype: int64
#  Married                 299798
# Single / not married     55268
# Civil marriage           36524
# Separated                27249
# Widow                    19671
# Name: NAME_FAMILY_STATUS, dtype: int64
#  House / apartment      393788
# With parents            19074
# Municipal apartment     14213
# Rented apartment         5974
# ...

# %%
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()
for x in application_details:
    if application_details[x].dtypes=='object':
        application_details[x] = le.fit_transform(application_details[x])
# we have transformed all the non numeric data columns into data columns
# Out:
# C:\Users\ASUS\AppData\Local\Temp/ipykernel_12200/4226759972.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   application_details[x] = le.fit_transform(application_details[x])

# %%
application_details
# Out:
#              ID  CODE_GENDER  FLAG_OWN_CAR  FLAG_OWN_REALTY  CNT_CHILDREN  \
# 0       5008804            1             1                1             0
# 1       5008805            1             1                1             0
# 2       5008806            1             1                1             0
# 3       5008808            0             0                1             0
# 4       5008809            0             0                1             0
# ...         ...          ...           ...              ...           ...
# 438552  6840104            1             0                1             0
# 438553  6840222            0             0                0             0
# 438554  6841878            0             0                0             0
# 438555  6842765            0             0                1             0
# 438556  6842885            0             0                1             0
#
#         AMT_INCOME_TOTAL  NAME_INCOME_TYPE  NAME_EDUCATION_TYPE  \
# ...

# %%
fig, ax= plt.subplots(nrows= 3, ncols = 3, figsize= (14,6))

sns.scatterplot(x='ID', y='CNT_CHILDREN', data=application_details, ax=ax[0][0], color= 'orange')
sns.scatterplot(x='ID', y='AMT_INCOME_TOTAL', data=application_details, ax=ax[0][1], color='orange')
sns.scatterplot(x='ID', y='DAYS_BIRTH', data=application_details, ax=ax[0][2])
sns.scatterplot(x='ID', y='DAYS_EMPLOYED', data=application_details, ax=ax[1][0])
sns.scatterplot(x='ID', y='FLAG_MOBIL', data=application_details, ax=ax[1][1])
sns.scatterplot(x='ID', y='FLAG_WORK_PHONE', data=application_details, ax=ax[1][2])
sns.scatterplot(x='ID', y='FLAG_PHONE', data=application_details, ax=ax[2][0])
sns.scatterplot(x='ID', y='FLAG_EMAIL', data=application_details, ax=ax[2][1])
sns.scatterplot(x='ID', y='CNT_FAM_MEMBERS', data=application_details, ax=ax[2][2], color= 'orange')
# Out:
# <AxesSubplot:xlabel='ID', ylabel='CNT_FAM_MEMBERS'>

# %%
# FOR CNT_CHILDREN COLUMN
q_hi = application_details['CNT_CHILDREN'].quantile(0.999)
q_low = application_details['CNT_CHILDREN'].quantile(0.001)
application_details = application_details[(application_details['CNT_CHILDREN']>q_low) & (application_details['CNT_CHILDREN']<q_hi)]

# %%
# FOR AMT_INCOME_TOTAL COLUMN
q_hi = application_details['AMT_INCOME_TOTAL'].quantile(0.999)
q_low = application_details['AMT_INCOME_TOTAL'].quantile(0.001)
application_details= application_details[(application_details['AMT_INCOME_TOTAL']>q_low) & (application_details['AMT_INCOME_TOTAL']<q_hi)]

# %%
#FOR CNT_FAM_MEMBERS COLUMN
q_hi = application_details['CNT_FAM_MEMBERS'].quantile(0.999)
q_low = application_details['CNT_FAM_MEMBERS'].quantile(0.001)
application_details= application_details[(application_details['CNT_FAM_MEMBERS']>q_low) & (application_details['CNT_FAM_MEMBERS']<q_hi)]

# %%
fig, ax= plt.subplots(nrows= 3, ncols = 3, figsize= (14,6))

sns.scatterplot(x='ID', y='CNT_CHILDREN', data=application_details, ax=ax[0][0], color= 'orange')
sns.scatterplot(x='ID', y='AMT_INCOME_TOTAL', data=application_details, ax=ax[0][1], color='orange')
sns.scatterplot(x='ID', y='DAYS_BIRTH', data=application_details, ax=ax[0][2])
sns.scatterplot(x='ID', y='DAYS_EMPLOYED', data=application_details, ax=ax[1][0])
sns.scatterplot(x='ID', y='FLAG_MOBIL', data=application_details, ax=ax[1][1])
sns.scatterplot(x='ID', y='FLAG_WORK_PHONE', data=application_details, ax=ax[1][2])
sns.scatterplot(x='ID', y='FLAG_PHONE', data=application_details, ax=ax[2][0])
sns.scatterplot(x='ID', y='FLAG_EMAIL', data=application_details, ax=ax[2][1])
sns.scatterplot(x='ID', y='CNT_FAM_MEMBERS', data=application_details, ax=ax[2][2], color= 'orange')
# Out:
# <AxesSubplot:xlabel='ID', ylabel='CNT_FAM_MEMBERS'>

# %%
credit_record
# Out:
#               ID  MONTHS_BALANCE STATUS
# 0        5001711               0      X
# 1        5001711              -1      0
# 2        5001711              -2      0
# 3        5001711              -3      0
# 4        5001712               0      C
# ...          ...             ...    ...
# 1048570  5150487             -25      C
# 1048571  5150487             -26      C
# 1048572  5150487             -27      C
# 1048573  5150487             -28      C
# 1048574  5150487             -29      C
#
# [1048575 rows x 3 columns]

# %%
credit_record['Months from today'] = credit_record['MONTHS_BALANCE']*-1
credit_record = credit_record.sort_values(['ID','Months from today'], ascending=True)
credit_record.head(10)
# we calculated months from today column to see how much old is the month
# we also sort the data according to ID and Months from today columns.
# Out:
#         ID  MONTHS_BALANCE STATUS  Months from today
# 0  5001711               0      X                  0
# 1  5001711              -1      0                  1
# 2  5001711              -2      0                  2
# 3  5001711              -3      0                  3
# 4  5001712               0      C                  0
# 5  5001712              -1      C                  1
# 6  5001712              -2      C                  2
# 7  5001712              -3      C                  3
# 8  5001712              -4      C                  4
# 9  5001712              -5      C                  5

# %%
credit_record['STATUS'].value_counts()
# Out:
# C    442031
# 0    383120
# X    209230
# 1     11090
# 5      1693
# 2       868
# 3       320
# 4       223
# Name: STATUS, dtype: int64

# %%
credit_record['STATUS'].replace({'C': 0, 'X' : 0}, inplace=True)
credit_record['STATUS'] = credit_record['STATUS'].astype('int')
credit_record['STATUS'] = credit_record['STATUS'].apply(lambda x:1 if x >= 2 else 0)
# replace the value C and X with 0 as it is the same type
# 1,2,3,4,5 are classified as 1 because they are the same type
# these will be our labels/prediction results for our model

# %%
credit_record['STATUS'].value_counts() 
# there is a problem here
# the data is oversampled for the labels
# 0 are 99%
# 1 are only 1% in the whole dataset
# we will need to address the oversampling issue in order to make sense of our analysis
# this will be done after when we combine both the datasets
# so first we will join the datasets
# Out:
# 0    1045471
# 1       3104
# Name: STATUS, dtype: int64

# %%
credit_record = credit_record.groupby('ID').agg(max).reset_index()
# Out:
#         ID  MONTHS_BALANCE  STATUS  Months from today
# 0  5001711               0       0                  3
# 1  5001712               0       0                 18
# 2  5001713               0       0                 21
# 3  5001714               0       0                 14
# 4  5001715               0       0                 59

# %%
df = application_details.join(credit_record.set_index('ID'), on='ID', how='inner')
df.drop(['Months from today', 'MONTHS_BALANCE'], axis=1, inplace=True)
# Out:
#          ID  CODE_GENDER  FLAG_OWN_CAR  FLAG_OWN_REALTY  CNT_CHILDREN  \
# 29  5008838            1             0                1             1
# 30  5008839            1             0                1             1
# 31  5008840            1             0                1             1
# 32  5008841            1             0                1             1
# 33  5008842            1             0                1             1
#
#     AMT_INCOME_TOTAL  NAME_INCOME_TYPE  NAME_EDUCATION_TYPE  \
# 29          405000.0                 0                    1
# 30          405000.0                 0                    1
# 31          405000.0                 0                    1
# 32          405000.0                 0                    1
# 33          405000.0                 0                    1
#
#     NAME_FAMILY_STATUS  NAME_HOUSING_TYPE  DAYS_BIRTH  DAYS_EMPLOYED  \
# 29                   1                  1      -11842          -2016
# ...

# %%
df
# Out:
#              ID  CODE_GENDER  FLAG_OWN_CAR  FLAG_OWN_REALTY  CNT_CHILDREN  \
# 29      5008838            1             0                1             1
# 30      5008839            1             0                1             1
# 31      5008840            1             0                1             1
# 32      5008841            1             0                1             1
# 33      5008842            1             0                1             1
# ...         ...          ...           ...              ...           ...
# 434779  5142964            1             0                0             1
# 434780  5142972            1             0                0             1
# 434782  5143342            1             0                0             1
# 434791  5145846            0             0                1             1
# 434805  5149190            1             1                0             1
#
#         AMT_INCOME_TOTAL  NAME_INCOME_TYPE  NAME_EDUCATION_TYPE  \
# ...

# %%
X = df.iloc[:,1:-1] # X value contains all the variables except labels
y = df.iloc[:,-1] # these are the labels

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X,y, test_size=0.3)
# we create the test train split first

# %%
from sklearn.preprocessing import MinMaxScaler
mms = MinMaxScaler()
X_scaled = pd.DataFrame(mms.fit_transform(X_train), columns=X_train.columns)
X_test_scaled = pd.DataFrame(mms.transform(X_test), columns=X_test.columns)
# we have now fit and transform the data into a scaler for accurate reading and results.

# %%
from imblearn.over_sampling import SMOTE
oversample = SMOTE()
X_balanced, y_balanced = oversample.fit_resample(X_scaled, y_train)
X_test_balanced, y_test_balanced = oversample.fit_resample(X_test_scaled, y_test)
# we have addressed the issue of oversampling here

# %%
y_train.value_counts()
# Out:
# 0    6553
# 1     108
# Name: STATUS, dtype: int64

# %%
y_balanced.value_counts()
# Out:
# 0    6553
# 1    6553
# Name: STATUS, dtype: int64

# %%
y_test.value_counts()
# Out:
# 0    2812
# 1      43
# Name: STATUS, dtype: int64

# %%
y_test_balanced.value_counts()
# Out:
# 0    2812
# 1    2812
# Name: STATUS, dtype: int64

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.neighbors import KNeighborsClassifier
from sklearn.svm import SVC
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from xgboost import XGBClassifier

# %%
classifiers = {
    "LogisticRegression" : LogisticRegression(),
    "KNeighbors" : KNeighborsClassifier(),
    "SVC" : SVC(),
    "DecisionTree" : DecisionTreeClassifier(),
    "RandomForest" : RandomForestClassifier(),
    "XGBoost" : XGBClassifier()
}

# %%
train_scores = []
test_scores = []

for key, classifier in classifiers.items():
    classifier.fit(X_balanced, y_balanced)
    train_score = classifier.score(X_balanced, y_balanced)
    train_scores.append(train_score)
    test_score = classifier.score(X_test_balanced, y_test_balanced)
    test_scores.append(test_score)

print(train_scores)
print(test_scores)
# Out:
# C:\Users\ASUS\anaconda3\lib\site-packages\xgboost\sklearn.py:1224: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# [17:58:37] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.5.1/src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [0.6556538989775675, 0.9844346101022432, 0.9200366244468182, 0.9948115367007477, 0.9948115367007477, 0.9945826339081337]
# ...

# %%
xgb = XGBClassifier()
model = xgb.fit(X_balanced, y_balanced)
prediction = xgb.predict(X_test_balanced)
# Out:
# [17:58:38] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.5.1/src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# C:\Users\ASUS\anaconda3\lib\site-packages\xgboost\sklearn.py:1224: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)

# %%
from sklearn.metrics import classification_report
print(classification_report(y_test_balanced, prediction))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.94      0.99      0.96      2812
#            1       0.99      0.93      0.96      2812
#
#     accuracy                           0.96      5624
#    macro avg       0.96      0.96      0.96      5624
# weighted avg       0.96      0.96      0.96      5624
